# %%
# !pip install pytesseract
# Out:
# Collecting pytesseract
#   Downloading pytesseract-0.3.10-py3-none-any.whl (14 kB)
# Requirement already satisfied: Pillow>=8.0.0 in c:\users\el-shenawy\anaconda3\lib\site-packages (from pytesseract) (9.3.0)
# Requirement already satisfied: packaging>=21.3 in c:\users\el-shenawy\anaconda3\lib\site-packages (from pytesseract) (22.0)
# Installing collected packages: pytesseract
# Successfully installed pytesseract-0.3.10
# WARNING: Ignoring invalid distribution -orch (c:\users\el-shenawy\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\el-shenawy\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\el-shenawy\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\el-shenawy\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\el-shenawy\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\el-shenawy\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\el-shenawy\anaconda3\lib\site-packages)

# %%
import cv2
import pytesseract
import os

# %%
os.chdir(r"E:")

# %%
pytesseract.pytesseract.tesseract_cmd=(r"C:\Program Files\Tesseract-OCR\tesseract.exe")

# %%
import matplotlib.pyplot as plt

# %%
img = cv2.imread("photooo.jpg")
img = cv2.resize (img,None, fx=0.5 , fy= 0.5)
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

#plt.imshow(cv2.cvtColor(gray,cv2.COLOR_BGR2RGB))



adaptive_Threshold = cv2.adaptiveThreshold(gray , 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C,cv2.THRESH_BINARY,85,30)
plt.imshow(cv2.cvtColor(adaptive_Threshold,cv2.COLOR_BGR2RGB))
config = "--psm 6"
text = pytesseract.image_to_string(adaptive_Threshold, lang = "eng" ,config = config)
print(text)
# Out:
# In signing this application | do hereby affirm thatthe statements
# are Wve io the best of my knowledge and believe and that any
# misrepresentation of facis or omissions, shall in the case of
# ‘ny employment be cause for dismissal, | also agree to
# take the prescribed medical examination and if employed.
# agree that my employment shall be in accordance with
# Company rules and regulations and any amendments
# hereto.
